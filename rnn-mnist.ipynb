# %%
import tensorflow as tf
import keras
from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
mnist = tf.keras.datasets.mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
print(training_images.shape)
print(test_images.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
training_images = training_images.reshape(20000, 784,1)
training_images = training_images[0:20000]
training_labels = training_labels[0:20000]
training_images = training_images/255.0
test_images = test_images.reshape(5000, 784, 1)
test_images = test_images[0:5000]
test_labels = test_labels[0:5000]
test_images = test_images/255.0

# %%
model = tf.keras.models.Sequential([
	tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(28, input_shape=(784,1), return_sequences=True)),
	tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(28)),
	tf.keras.layers.Flatten(),
	tf.keras.layers.Dense(64, activation='relu'),
	tf.keras.layers.Dense(10, activation='softmax')
	])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(training_images, training_labels, batch_size = 50, epochs=10)
# Out:
# Epoch 1/10
# 400/400 [==============================] - 57s 115ms/step - loss: 2.3017 - accuracy: 0.1117
# Epoch 2/10
# 400/400 [==============================] - 46s 115ms/step - loss: 2.3011 - accuracy: 0.1141
# Epoch 3/10
# 400/400 [==============================] - 46s 114ms/step - loss: 2.3011 - accuracy: 0.1141
# Epoch 4/10
# 400/400 [==============================] - 46s 114ms/step - loss: 2.3010 - accuracy: 0.1141
# Epoch 5/10
# 400/400 [==============================] - 46s 115ms/step - loss: 2.3009 - accuracy: 0.1141
# Epoch 6/10
# 400/400 [==============================] - 46s 114ms/step - loss: 2.3009 - accuracy: 0.1141
# Epoch 7/10
# 400/400 [==============================] - 46s 115ms/step - loss: 2.3010 - accuracy: 0.1141
# Epoch 8/10
# 400/400 [==============================] - 46s 114ms/step - loss: 2.3009 - accuracy: 0.1141
# Epoch 9/10
# 400/400 [==============================] - 46s 115ms/step - loss: 2.3009 - accuracy: 0.1141
# Epoch 10/10
# ...

# %%
model.evaluate(test_images, test_labels)
# Out:
# 157/157 [==============================] - 10s 51ms/step - loss: 2.3014 - accuracy: 0.1142
# [2.301406145095825, 0.11420000344514847]
