# %%
import os
import tensorflow as tf
import keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from os import getcwd
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
cifar10 = tf.keras.datasets.cifar10
(training_images, training_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 5s 0us/step

# %%
cifar10 = tf.keras.datasets.cifar10
(training_images, training_labels), (test_images, test_labels) = cifar10.load_data()

# %%
training_images = training_images.reshape(50000, 1024, 3)
training_images = training_images[0:10000]
training_labels = training_labels[0:10000]
training_images = training_images/255.0
test_images = test_images.reshape(10000, 1024, 3)
test_images = test_images[0:5000]
test_labels = test_labels[0:5000]
test_images = test_images/255.0

# %%
model = tf.keras.models.Sequential([
	tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, input_shape=(1024,3), return_sequences=True)),
	tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
	tf.keras.layers.Flatten(),
	tf.keras.layers.Dense(64, activation='relu'),
	tf.keras.layers.Dense(10, activation='softmax')
	])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(training_images, training_labels, batch_size = 50, epochs=10)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 41s 147ms/step - loss: 2.1410 - accuracy: 0.1938
# Epoch 2/10
# 200/200 [==============================] - 29s 144ms/step - loss: 2.0346 - accuracy: 0.2432
# Epoch 3/10
# 200/200 [==============================] - 29s 143ms/step - loss: 1.9889 - accuracy: 0.2666
# Epoch 4/10
# 200/200 [==============================] - 28s 142ms/step - loss: 1.9699 - accuracy: 0.2678
# Epoch 5/10
# 200/200 [==============================] - 28s 142ms/step - loss: 1.9523 - accuracy: 0.2822
# Epoch 6/10
# 200/200 [==============================] - 28s 142ms/step - loss: 1.9474 - accuracy: 0.2845
# Epoch 7/10
# 200/200 [==============================] - 29s 143ms/step - loss: 2.0320 - accuracy: 0.2585
# Epoch 8/10
# 200/200 [==============================] - 29s 144ms/step - loss: 1.9942 - accuracy: 0.2712
# Epoch 9/10
# 200/200 [==============================] - 29s 144ms/step - loss: 2.0104 - accuracy: 0.2612
# Epoch 10/10
# 200/200 [==============================] - 29s 144ms/step - loss: 1.9600 - accuracy: 0.2826

# %%
model.evaluate(test_images, test_labels)
# Out:
# 157/157 [==============================] - 12s 63ms/step - loss: 1.9504 - accuracy: 0.2840
# [1.950411319732666, 0.2840000092983246]
